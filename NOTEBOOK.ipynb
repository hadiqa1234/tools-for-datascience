# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Hadiqa Shahid__  <br> I am a bioinformatics student

# %% [markdown]
# *I am interested in data science because it is  an interesting field and it have a vast scope in future as well*

# %% [markdown]
# ### My code is supposed to do a simple addition

# %%
1+1+0+80+527277+80+8
# Out:
# 527447

# %% [markdown]
# My favourite Fruits:<br> **<br>1.Apple <br>2. Banana <br>3. orange<br>4. grapes**<br>
# link to my fiver id:
# [fiver id link ](https://www.fiverr.com/hadiqa125?up_rollout=true)
# <p>I will display a diamond &#9670;</p>
# <p>I will display a black sqaure: &#x25A0;</p>
